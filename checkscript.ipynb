# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

image = Image.open('images/0015.tiff')
image = Image.open('images/sydney.png')

# image_np = np.array(image)

pixels = np.array(image)
print('Data Type: %s' % pixels.dtype)
print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))
pixels = pixels.astype('float32')
pixels /= 255.0
print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))

pixels_norm = (pixels-np.min(pixels))/(np.max(pixels)-np.min(pixels))

# Create a figure and axes
fig, ax = plt.subplots()

ax.imshow(pixels_norm, cmap='gray')

ax.set_title("Normalized Image")
ax.axis('off')

plt.show()
# Out:
# Data Type: uint8
# Min: 3.000, Max: 255.000
# Min: 0.012, Max: 1.000

# %%
fig, ax = plt.subplots()

ax.imshow(pixels, cmap='gray')

ax.set_title("Normalized Image")
ax.axis('off')

plt.show()

# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

image = Image.open('images/0015.tiff')
image = np.array(image)

# %%
# Normalize image array to [0, 1]
normalized_image = image.astype(np.float32) / 65535.0

# Normalize image array to [-1, 1]
#normalized_image = (image.astype(np.float32) - 32767.5) / 32767.5

print("Original image:")
print(image)
print("\nNormalized image to [0, 1]:")
print(normalized_image)
# Out:
# Original image:
# [[16852 16940 16900 ... 25152 24716 24104]
#  [16644 16796 16348 ... 24900 24984 24660]
#  [16696 16764 16636 ... 24372 24596 24644]
#  ...
#  [13620 13516 13612 ... 21952 21724 21804]
#  [13800 13832 13656 ... 22168 21744 21464]
#  [13588 13544 13716 ... 21376 21276 21628]]
#
# Normalized image to [0, 1]:
# [[0.25714505 0.25848782 0.25787747 ... 0.38379493 0.37714198 0.36780345]
#  [0.25397116 0.25629053 0.24945448 ... 0.37994966 0.3812314  0.3762875 ]
#  [0.25476462 0.25580224 0.2538491  ... 0.37189287 0.3753109  0.37604335]
#  ...
#  [0.20782788 0.20624094 0.20770581 ... 0.33496606 0.331487   0.3327077 ]
#  [0.21057451 0.21106279 0.2083772  ... 0.338262   0.33179218 0.32751966]
#  [0.20733958 0.2066682  0.20929274 ... 0.32617685 0.32465094 0.33002213]]

# %%
fig, ax = plt.subplots()

ax.imshow(image, cmap='gray')

ax.set_title("Normalized Image")
ax.axis('off')

plt.show()

# %%
# import necessary packages
import numpy as np
  
# create an array
'''data = np.array([[10, 20], [30, 40], 
                 [5, 15], [0, 10]])'''
  
normalizedData = (image-np.min(image))/(np.max(image)-np.min(image))
normalizedData
# normalized data using 

Image.fromarray(image).show()

# %%
fig, ax = plt.subplots()
ax.imshow(normalizedData, cmap='gray')
ax.set_title("Normalized Image")
ax.axis('off')
plt.show()

# %%
np.max(normalizedData)
# Out:
# 1.0
